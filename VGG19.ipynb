# %% [markdown]
# <a href="https://colab.research.google.com/github/himanshu-tawra/COVID-19-Detector-Flask-App-from-Chest-X-ray-Images-with-Keras-and-Deep-Learning/blob/master/VGG19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.layers import *
from keras.models import *
from keras.preprocessing import image
from glob import glob
from keras.preprocessing.image import ImageDataGenerator
import os
from keras.applications.vgg19 import VGG19
import keras

# %%
IMAGE_SIZE = [224,224]

# %%
vgg = VGG19(input_shape= IMAGE_SIZE + [3] , weights='imagenet',include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step

# %%
for layer in vgg.layers:
  layer.trainable = False

# %%
vgg_output = vgg.output

# %%
flatten = Flatten()(vgg_output)


output_layer = Dense(3,activation='softmax')(flatten)

# %%
model = Model(inputs = vgg.input,outputs = output_layer)

# %%
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 3)                 75267
# =================================================================
# Total params: 20,099,651
# Trainable params: 75,267
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
model.compile(
    optimizer=keras.optimizers.Adam(0.00001),  # Low learning rate
    loss = 'categorical_crossentropy',
    metrics = ['accuracy']
)

# %%
training_data_gen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.2,
    height_shift_range=0.2,
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

# %%
val_data_gen = ImageDataGenerator(
    rescale = 1./255.
)

# %%
training_set = training_data_gen.flow_from_directory(
    '/content/drive/My Drive/Data/train/',
    target_size = (224,224),
    class_mode = 'categorical',
    batch_size = 32
)
# Out:
# Found 5144 images belonging to 3 classes.

# %%
val_set = val_data_gen.flow_from_directory(
    '/content/drive/My Drive/Data/test/',
    target_size = (224,224),
    class_mode = 'categorical',
    batch_size = 32
)
# Out:
# Found 1288 images belonging to 3 classes.

# %%
from keras.callbacks import ModelCheckpoint , EarlyStopping

#checkpoint = ModelCheckpoint('vgg16_model.h5',monitor='val_loss',mode='min',save_best_only=True,verbose=1)
callback_list = [EarlyStopping(verbose=True, patience=10, monitor='val_loss'),
                          ModelCheckpoint('vgg19_new.h5', monitor='val_loss', verbose=True, save_best_only=True)]
#callbacks_list = [checkpoint]

#model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=15,batch_size=32, callbacks=checkpoint)

# %%
r = model.fit(
    training_set,
    epochs = 100,
    validation_data = val_set,
    validation_steps = len(val_set),
    steps_per_epoch = len(training_set),
    callbacks = callback_list
)
# Out:
# Epoch 1/100
# 161/161 [==============================] - ETA: 0s - loss: 0.7697 - accuracy: 0.6730
# Epoch 00001: val_loss improved from inf to 0.66400, saving model to vgg19_new.h5
# 161/161 [==============================] - 2283s 14s/step - loss: 0.7697 - accuracy: 0.6730 - val_loss: 0.6640 - val_accuracy: 0.7516
# Epoch 2/100
# 161/161 [==============================] - ETA: 0s - loss: 0.6350 - accuracy: 0.7323
# Epoch 00002: val_loss improved from 0.66400 to 0.55911, saving model to vgg19_new.h5
# 161/161 [==============================] - 209s 1s/step - loss: 0.6350 - accuracy: 0.7323 - val_loss: 0.5591 - val_accuracy: 0.8098
# Epoch 3/100
# 161/161 [==============================] - ETA: 0s - loss: 0.5569 - accuracy: 0.7673
# Epoch 00003: val_loss improved from 0.55911 to 0.49571, saving model to vgg19_new.h5
# 161/161 [==============================] - 205s 1s/step - loss: 0.5569 - accuracy: 0.7673 - val_loss: 0.4957 - val_accuracy: 0.8090
# Epoch 4/100
# 161/161 [==============================] - ETA: 0s - loss: 0.4990 - accuracy: 0.7912
# Epoch 00004: val_loss improved from 0.49571 to 0.44660, saving model to vgg19_new.h5
# 161/161 [==============================] - 205s 1s/step - loss: 0.4990 - accuracy: 0.7912 - val_loss: 0.4466 - val_accuracy: 0.8121
# Epoch 5/100
# 161/161 [==============================] - ETA: 0s - loss: 0.4577 - accuracy: 0.8093
# Epoch 00005: val_loss improved from 0.44660 to 0.42181, saving model to vgg19_new.h5
# 161/161 [==============================] - 205s 1s/step - loss: 0.4577 - accuracy: 0.8093 - val_loss: 0.4218 - val_accuracy: 0.8160
# Epoch 6/100
# 161/161 [==============================] - ETA: 0s - loss: 0.4366 - accuracy: 0.8108
# Epoch 00006: val_loss improved from 0.42181 to 0.40261, saving model to vgg19_new.h5
# 161/161 [==============================] - 203s 1s/step - loss: 0.4366 - accuracy: 0.8108 - val_loss: 0.4026 - val_accuracy: 0.8238
# Epoch 7/100
# 161/161 [==============================] - ETA: 0s - loss: 0.4084 - accuracy: 0.8351
# Epoch 00007: val_loss improved from 0.40261 to 0.37244, saving model to vgg19_new.h5
# 161/161 [==============================] - 203s 1s/step - loss: 0.4084 - accuracy: 0.8351 - val_loss: 0.3724 - val_accuracy: 0.8315
# Epoch 8/100
# 161/161 [==============================] - ETA: 0s - loss: 0.3892 - accuracy: 0.8447
# Epoch 00008: val_loss improved from 0.37244 to 0.36918, saving model to vgg19_new.h5
# 161/161 [==============================] - 203s 1s/step - loss: 0.3892 - accuracy: 0.8447 - val_loss: 0.3692 - val_accuracy: 0.8432
# Epoch 9/100
# 161/161 [==============================] - ETA: 0s - loss: 0.3709 - accuracy: 0.8544
# Epoch 00009: val_loss improved from 0.36918 to 0.33678, saving model to vgg19_new.h5
# 161/161 [==============================] - 202s 1s/step - loss: 0.3709 - accuracy: 0.8544 - val_loss: 0.3368 - val_accuracy: 0.8587
# Epoch 10/100
# 161/161 [==============================] - ETA: 0s - loss: 0.3632 - accuracy: 0.8614
# Epoch 00010: val_loss improved from 0.33678 to 0.32948, saving model to vgg19_new.h5
# 161/161 [==============================] - 201s 1s/step - loss: 0.3632 - accuracy: 0.8614 - val_loss: 0.3295 - val_accuracy: 0.8595
# Epoch 11/100
# 161/161 [==============================] - ETA: 0s - loss: 0.3579 - accuracy: 0.8620
# Epoch 00011: val_loss improved from 0.32948 to 0.32706, saving model to vgg19_new.h5
# 161/161 [==============================] - 200s 1s/step - loss: 0.3579 - accuracy: 0.8620 - val_loss: 0.3271 - val_accuracy: 0.8634
# Epoch 12/100
# 161/161 [==============================] - ETA: 0s - loss: 0.3438 - accuracy: 0.8688
# Epoch 00012: val_loss improved from 0.32706 to 0.30302, saving model to vgg19_new.h5
# 161/161 [==============================] - 200s 1s/step - loss: 0.3438 - accuracy: 0.8688 - val_loss: 0.3030 - val_accuracy: 0.8773
# Epoch 13/100
# 161/161 [==============================] - ETA: 0s - loss: 0.3300 - accuracy: 0.8799
# Epoch 00013: val_loss improved from 0.30302 to 0.30208, saving model to vgg19_new.h5
# 161/161 [==============================] - 199s 1s/step - loss: 0.3300 - accuracy: 0.8799 - val_loss: 0.3021 - val_accuracy: 0.8742
# Epoch 14/100
# 161/161 [==============================] - ETA: 0s - loss: 0.3249 - accuracy: 0.8804
# Epoch 00014: val_loss improved from 0.30208 to 0.29192, saving model to vgg19_new.h5
# 161/161 [==============================] - 200s 1s/step - loss: 0.3249 - accuracy: 0.8804 - val_loss: 0.2919 - val_accuracy: 0.8843
# Epoch 15/100
# 161/161 [==============================] - ETA: 0s - loss: 0.3139 - accuracy: 0.8896
# Epoch 00015: val_loss improved from 0.29192 to 0.28560, saving model to vgg19_new.h5
# 161/161 [==============================] - 200s 1s/step - loss: 0.3139 - accuracy: 0.8896 - val_loss: 0.2856 - val_accuracy: 0.8882
# Epoch 16/100
# 161/161 [==============================] - ETA: 0s - loss: 0.3114 - accuracy: 0.8882
# Epoch 00016: val_loss did not improve from 0.28560
# 161/161 [==============================] - 199s 1s/step - loss: 0.3114 - accuracy: 0.8882 - val_loss: 0.2864 - val_accuracy: 0.8843
# Epoch 17/100
# 161/161 [==============================] - ETA: 0s - loss: 0.3045 - accuracy: 0.8880
# Epoch 00017: val_loss improved from 0.28560 to 0.28558, saving model to vgg19_new.h5
# 161/161 [==============================] - 198s 1s/step - loss: 0.3045 - accuracy: 0.8880 - val_loss: 0.2856 - val_accuracy: 0.8812
# Epoch 18/100
# 161/161 [==============================] - ETA: 0s - loss: 0.2956 - accuracy: 0.8960
# Epoch 00018: val_loss improved from 0.28558 to 0.26904, saving model to vgg19_new.h5
# 161/161 [==============================] - 198s 1s/step - loss: 0.2956 - accuracy: 0.8960 - val_loss: 0.2690 - val_accuracy: 0.8967
# Epoch 19/100
# 161/161 [==============================] - ETA: 0s - loss: 0.2940 - accuracy: 0.8937
# Epoch 00019: val_loss improved from 0.26904 to 0.25997, saving model to vgg19_new.h5
# 161/161 [==============================] - 197s 1s/step - loss: 0.2940 - accuracy: 0.8937 - val_loss: 0.2600 - val_accuracy: 0.9030
# Epoch 20/100
# 161/161 [==============================] - ETA: 0s - loss: 0.2883 - accuracy: 0.8968
# Epoch 00020: val_loss did not improve from 0.25997
# 161/161 [==============================] - 198s 1s/step - loss: 0.2883 - accuracy: 0.8968 - val_loss: 0.2706 - val_accuracy: 0.8936
# Epoch 21/100
# 161/161 [==============================] - ETA: 0s - loss: 0.2822 - accuracy: 0.8977
# Epoch 00021: val_loss improved from 0.25997 to 0.25674, saving model to vgg19_new.h5
# 161/161 [==============================] - 199s 1s/step - loss: 0.2822 - accuracy: 0.8977 - val_loss: 0.2567 - val_accuracy: 0.9037
# Epoch 22/100
# 161/161 [==============================] - ETA: 0s - loss: 0.2786 - accuracy: 0.9020
# Epoch 00022: val_loss improved from 0.25674 to 0.25388, saving model to vgg19_new.h5
# 161/161 [==============================] - 199s 1s/step - loss: 0.2786 - accuracy: 0.9020 - val_loss: 0.2539 - val_accuracy: 0.9022
# Epoch 23/100
# 161/161 [==============================] - ETA: 0s - loss: 0.2734 - accuracy: 0.9028
# Epoch 00023: val_loss did not improve from 0.25388
# 161/161 [==============================] - 197s 1s/step - loss: 0.2734 - accuracy: 0.9028 - val_loss: 0.2544 - val_accuracy: 0.9014
# Epoch 24/100
# 161/161 [==============================] - ETA: 0s - loss: 0.2730 - accuracy: 0.8993
# Epoch 00024: val_loss improved from 0.25388 to 0.25065, saving model to vgg19_new.h5
# 161/161 [==============================] - 196s 1s/step - loss: 0.2730 - accuracy: 0.8993 - val_loss: 0.2507 - val_accuracy: 0.9045
# Epoch 25/100
# 161/161 [==============================] - ETA: 0s - loss: 0.2668 - accuracy: 0.9102
# Epoch 00025: val_loss improved from 0.25065 to 0.24053, saving model to vgg19_new.h5
# 161/161 [==============================] - 195s 1s/step - loss: 0.2668 - accuracy: 0.9102 - val_loss: 0.2405 - val_accuracy: 0.9154
# Epoch 26/100
# 161/161 [==============================] - ETA: 0s - loss: 0.2666 - accuracy: 0.9034
# Epoch 00026: val_loss did not improve from 0.24053
# 161/161 [==============================] - 194s 1s/step - loss: 0.2666 - accuracy: 0.9034 - val_loss: 0.2482 - val_accuracy: 0.9030
# Epoch 27/100
# 161/161 [==============================] - ETA: 0s - loss: 0.2539 - accuracy: 0.9106
# Epoch 00027: val_loss did not improve from 0.24053
# 161/161 [==============================] - 193s 1s/step - loss: 0.2539 - accuracy: 0.9106 - val_loss: 0.2509 - val_accuracy: 0.9006
# Epoch 28/100
# 161/161 [==============================] - ETA: 0s - loss: 0.2504 - accuracy: 0.9135
# Epoch 00028: val_loss did not improve from 0.24053
# 161/161 [==============================] - 192s 1s/step - loss: 0.2504 - accuracy: 0.9135 - val_loss: 0.2417 - val_accuracy: 0.9037
# Epoch 29/100
# 161/161 [==============================] - ETA: 0s - loss: 0.2505 - accuracy: 0.9147
# Epoch 00029: val_loss improved from 0.24053 to 0.23880, saving model to vgg19_new.h5
# 161/161 [==============================] - 193s 1s/step - loss: 0.2505 - accuracy: 0.9147 - val_loss: 0.2388 - val_accuracy: 0.9076
# Epoch 30/100
# 161/161 [==============================] - ETA: 0s - loss: 0.2503 - accuracy: 0.9114
# Epoch 00030: val_loss improved from 0.23880 to 0.23032, saving model to vgg19_new.h5
# 161/161 [==============================] - 194s 1s/step - loss: 0.2503 - accuracy: 0.9114 - val_loss: 0.2303 - val_accuracy: 0.9138
# Epoch 31/100
# 161/161 [==============================] - ETA: 0s - loss: 0.2435 - accuracy: 0.9182
# Epoch 00031: val_loss improved from 0.23032 to 0.22115, saving model to vgg19_new.h5
# 161/161 [==============================] - 195s 1s/step - loss: 0.2435 - accuracy: 0.9182 - val_loss: 0.2211 - val_accuracy: 0.9200
# Epoch 32/100
# 161/161 [==============================] - ETA: 0s - loss: 0.2432 - accuracy: 0.9178
# Epoch 00032: val_loss did not improve from 0.22115
# 161/161 [==============================] - 194s 1s/step - loss: 0.2432 - accuracy: 0.9178 - val_loss: 0.2357 - val_accuracy: 0.9084
# Epoch 33/100
# 161/161 [==============================] - ETA: 0s - loss: 0.2449 - accuracy: 0.9164
# Epoch 00033: val_loss did not improve from 0.22115
# 161/161 [==============================] - 195s 1s/step - loss: 0.2449 - accuracy: 0.9164 - val_loss: 0.2259 - val_accuracy: 0.9146
# Epoch 34/100
# 161/161 [==============================] - ETA: 0s - loss: 0.2403 - accuracy: 0.9154
# Epoch 00034: val_loss did not improve from 0.22115
# 161/161 [==============================] - 194s 1s/step - loss: 0.2403 - accuracy: 0.9154 - val_loss: 0.2301 - val_accuracy: 0.9099
# Epoch 35/100
# 161/161 [==============================] - ETA: 0s - loss: 0.2380 - accuracy: 0.9187
# Epoch 00035: val_loss improved from 0.22115 to 0.21356, saving model to vgg19_new.h5
# 161/161 [==============================] - 195s 1s/step - loss: 0.2380 - accuracy: 0.9187 - val_loss: 0.2136 - val_accuracy: 0.9247
# Epoch 36/100
# 161/161 [==============================] - ETA: 0s - loss: 0.2312 - accuracy: 0.9226
# Epoch 00036: val_loss did not improve from 0.21356
# 161/161 [==============================] - 195s 1s/step - loss: 0.2312 - accuracy: 0.9226 - val_loss: 0.2443 - val_accuracy: 0.9045
# Epoch 37/100
# 161/161 [==============================] - ETA: 0s - loss: 0.2307 - accuracy: 0.9234
# Epoch 00037: val_loss did not improve from 0.21356
# 161/161 [==============================] - 192s 1s/step - loss: 0.2307 - accuracy: 0.9234 - val_loss: 0.2306 - val_accuracy: 0.9092
# Epoch 38/100
# 161/161 [==============================] - ETA: 0s - loss: 0.2305 - accuracy: 0.9248
# Epoch 00038: val_loss did not improve from 0.21356
# 161/161 [==============================] - 193s 1s/step - loss: 0.2305 - accuracy: 0.9248 - val_loss: 0.2258 - val_accuracy: 0.9138
# Epoch 39/100
# 161/161 [==============================] - ETA: 0s - loss: 0.2256 - accuracy: 0.9219
# Epoch 00039: val_loss did not improve from 0.21356
# 161/161 [==============================] - 192s 1s/step - loss: 0.2256 - accuracy: 0.9219 - val_loss: 0.2166 - val_accuracy: 0.9185
# Epoch 40/100
# 161/161 [==============================] - ETA: 0s - loss: 0.2275 - accuracy: 0.9213
# Epoch 00040: val_loss improved from 0.21356 to 0.21319, saving model to vgg19_new.h5
# 161/161 [==============================] - 195s 1s/step - loss: 0.2275 - accuracy: 0.9213 - val_loss: 0.2132 - val_accuracy: 0.9177
# Epoch 41/100
# 161/161 [==============================] - ETA: 0s - loss: 0.2242 - accuracy: 0.9226
# Epoch 00041: val_loss did not improve from 0.21319
# 161/161 [==============================] - 194s 1s/step - loss: 0.2242 - accuracy: 0.9226 - val_loss: 0.2389 - val_accuracy: 0.9045
# Epoch 42/100
# 161/161 [==============================] - ETA: 0s - loss: 0.2285 - accuracy: 0.9228
# Epoch 00042: val_loss improved from 0.21319 to 0.20838, saving model to vgg19_new.h5
# 161/161 [==============================] - 197s 1s/step - loss: 0.2285 - accuracy: 0.9228 - val_loss: 0.2084 - val_accuracy: 0.9247
# Epoch 43/100
# 161/161 [==============================] - ETA: 0s - loss: 0.2227 - accuracy: 0.9263
# Epoch 00043: val_loss did not improve from 0.20838
# 161/161 [==============================] - 201s 1s/step - loss: 0.2227 - accuracy: 0.9263 - val_loss: 0.2340 - val_accuracy: 0.9068
# Epoch 44/100
# 161/161 [==============================] - ETA: 0s - loss: 0.2247 - accuracy: 0.9215
# Epoch 00044: val_loss did not improve from 0.20838
# 161/161 [==============================] - 197s 1s/step - loss: 0.2247 - accuracy: 0.9215 - val_loss: 0.2158 - val_accuracy: 0.9193
# Epoch 45/100
# 161/161 [==============================] - ETA: 0s - loss: 0.2173 - accuracy: 0.9290
# Epoch 00045: val_loss did not improve from 0.20838
# 161/161 [==============================] - 196s 1s/step - loss: 0.2173 - accuracy: 0.9290 - val_loss: 0.2128 - val_accuracy: 0.9193
# Epoch 46/100
# 161/161 [==============================] - ETA: 0s - loss: 0.2156 - accuracy: 0.9288
# Epoch 00046: val_loss did not improve from 0.20838
# 161/161 [==============================] - 196s 1s/step - loss: 0.2156 - accuracy: 0.9288 - val_loss: 0.2161 - val_accuracy: 0.9169
# Epoch 47/100
# 161/161 [==============================] - ETA: 0s - loss: 0.2156 - accuracy: 0.9273
# Epoch 00047: val_loss did not improve from 0.20838
# 161/161 [==============================] - 194s 1s/step - loss: 0.2156 - accuracy: 0.9273 - val_loss: 0.2203 - val_accuracy: 0.9154
# Epoch 48/100
# 161/161 [==============================] - ETA: 0s - loss: 0.2199 - accuracy: 0.9238
# Epoch 00048: val_loss did not improve from 0.20838
# 161/161 [==============================] - 194s 1s/step - loss: 0.2199 - accuracy: 0.9238 - val_loss: 0.2267 - val_accuracy: 0.9084
# Epoch 49/100
# 161/161 [==============================] - ETA: 0s - loss: 0.2180 - accuracy: 0.9269
# Epoch 00049: val_loss did not improve from 0.20838
# 161/161 [==============================] - 194s 1s/step - loss: 0.2180 - accuracy: 0.9269 - val_loss: 0.2149 - val_accuracy: 0.9169
# Epoch 50/100
# 161/161 [==============================] - ETA: 0s - loss: 0.2130 - accuracy: 0.9300
# Epoch 00050: val_loss did not improve from 0.20838
# 161/161 [==============================] - 194s 1s/step - loss: 0.2130 - accuracy: 0.9300 - val_loss: 0.2099 - val_accuracy: 0.9208
# Epoch 51/100
# 161/161 [==============================] - ETA: 0s - loss: 0.2085 - accuracy: 0.9288
# Epoch 00051: val_loss did not improve from 0.20838
# 161/161 [==============================] - 194s 1s/step - loss: 0.2085 - accuracy: 0.9288 - val_loss: 0.2248 - val_accuracy: 0.9099
# Epoch 52/100
# 161/161 [==============================] - ETA: 0s - loss: 0.2114 - accuracy: 0.9236
# Epoch 00052: val_loss did not improve from 0.20838
# 161/161 [==============================] - 193s 1s/step - loss: 0.2114 - accuracy: 0.9236 - val_loss: 0.2184 - val_accuracy: 0.9115
# Epoch 00052: early stopping

# %%
test_pred = []
test_actual = []
label_dict = {
    0 : "Covid",
    1 : "Normal",
    2 : "Pneumonia"
}

# %%
def image_preprocessing(path):
  for filename in os.listdir(path):

    if path == '/content/drive/My Drive/Data/test/COVID19':
      filepath = os.path.join(path,filename)
      test_image = image.load_img(filepath,target_size=(224,224))
      image_array = image.img_to_array(test_image)
      image_array = np.expand_dims(image_array,axis = 0)
      rescaled_image = image_array/255. 
      predicted_image = model.predict(rescaled_image)
      predicted_image = label_dict[predicted_image.argmax()]
      test_pred.append(predicted_image)
      test_actual.append('Covid')

    elif path == '/content/drive/My Drive/Data/test/NORMAL':
      filepath = os.path.join(path,filename)
      test_image = image.load_img(filepath,target_size=(224,224))
      image_array = image.img_to_array(test_image)
      image_array = np.expand_dims(image_array,axis = 0)
      rescaled_image = image_array/255. 
      predicted_image = model.predict(rescaled_image)
      predicted_image = label_dict[predicted_image.argmax()]
      test_pred.append(predicted_image)
      test_actual.append('Normal')

    elif path == '/content/drive/My Drive/Data/test/PNEUMONIA':
      filepath = os.path.join(path,filename)
      test_image = image.load_img(filepath,target_size=(224,224))
      image_array = image.img_to_array(test_image)
      image_array = np.expand_dims(image_array,axis = 0)
      rescaled_image = image_array/255. 
      predicted_image = model.predict(rescaled_image)
      predicted_image = label_dict[predicted_image.argmax()]
      test_pred.append(predicted_image)
      test_actual.append('Pneumonia')

# %%
covid_path = '/content/drive/My Drive/Data/test/COVID19'
normal_path = '/content/drive/My Drive/Data/test/NORMAL'
pneumonia_path = '/content/drive/My Drive/Data/test/PNEUMONIA'

# %%
image_preprocessing(covid_path)
image_preprocessing(normal_path)
image_preprocessing(pneumonia_path)

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
def plot_confusion_matrix(normalize):
  classes = ['COVID','NORMAL','PNEUMONIA']
  tick_marks = [0.5,1.5,2.5]
  cn = confusion_matrix(test_actual,test_pred,normalize=normalize)
  sns.heatmap(cn,cmap='plasma',annot=True)
  plt.xticks(tick_marks, classes)
  plt.yticks(tick_marks, classes)
  plt.title('Confusion Matrix')
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.savefig('confusion_mat.png')
  plt.show()
  print(cn)

print('Confusion Matrix without Normalization')
plot_confusion_matrix(normalize=None)
plot_confusion_matrix('true')
# Out:
# Confusion Matrix without Normalization
# [[100   7   9]
#  [  0 295  22]
#  [  0  76 779]]
# [[0.86206897 0.06034483 0.07758621]
#  [0.         0.93059937 0.06940063]
#  [0.         0.08888889 0.91111111]]

# %%
from sklearn.metrics import classification_report
print(classification_report(test_actual, test_pred))
# Out:
#               precision    recall  f1-score   support
#
#        Covid       1.00      0.86      0.93       116
#       Normal       0.78      0.93      0.85       317
#    Pneumonia       0.96      0.91      0.94       855
#
#     accuracy                           0.91      1288
#    macro avg       0.91      0.90      0.90      1288
# weighted avg       0.92      0.91      0.91      1288

# %%
plt.figure(figsize=(5,5))

plt.plot(r.history['accuracy'])
plt.plot(r.history['val_accuracy'])

plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
plt.savefig('vgg_chest_accuracy.png')
plt.show()

# %%
plt.figure(figsize=(5,5))

plt.plot(r.history['loss'])
plt.plot(r.history['val_loss'])

plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
plt.savefig('vgg_chest_loss.png')
plt.show()

# %%
from keras.utils import plot_model

# %%
plot_model(model, show_shapes=True, to_file='model__vgg.png')
